# %% [markdown]
# <a href="https://colab.research.google.com/github/barve27/Project-1/blob/main/Polyfit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.array([0,1,2,3,4,5])
y=np.array([2.1,3.9,7.2,10.8,15.3,20.5])

degree=2
coefficients=np.polyfit(x,y,degree)
polynomial_func=np.poly1d(coefficients)

X_curve=np.linspace(min(x),max(x),100)
y_curve=polynomial_func(X_curve)

plt.scatter(x,y,label='Data Points')
plt.plot(X_curve,y_curve,color='red',label='polynomial curve(Degree{})'.format(degree))
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Polynomial Curve Fitting')
plt.legend()
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
